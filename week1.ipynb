# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
print("Hello World")
# Out:
# Hello World

# %%
name = "Sorrawit Suppalabwattana"
print ("Hello " + name + ", are you ok??")
# Out:
# Hello Sorrawit Suppalabwattana, are you ok??21

# %%
country = input("Where are you from =")
# Out:
# Where are you from = Thailand

# %%
print("I am from " + country)
# Out:
# I am from Thailand

# %%
age = input("What is your age =")
# Out:
# What is your age = 20

# %%
print("I am " + age + " years old")
# Out:
# I am 20 years old

# %%
tenyears_age = (age + 10)
print(tenyears_age)
# Out:
# 30

# %% [markdown]
# Ex1

# %%
a = 2
b = 5
a + b
# Out:
# 7

# %%
pi = 3.14

# %%
print("Pi is " + str(pi))
# Out:
# Pi is 3.14

# %% [markdown]
# Ex2

# %%
a = input("What is your A = ")
b = input("What is your B = ")
c = int(a) + int(b)
print(c)
# Out:
# What is your A =  2
# What is your B =  3
# 5

# %% [markdown]
# Ex3

# %%
msg = "A " + "B"
print(msg)
# Out:
# A B

# %%
"s" in "sorrawit"
# Out:
# True

# %% [markdown]
# Case Sensitive

# %%
name = "Sorrawit"
age = 20
msg = f"Hello my name is {name} and my age is {age}"
print(msg)
# Out:
# Hello my name is Sorrawit and my age is 20

# %%
a = "Price"
b = 2000

print("%s is %.2f" % (a,b))
# Out:
# Price is 2000.00

# %%
a = "Price"
b = 2000

print(a + " is %.2f" % b)
# Out:
# Price is 2000.00

# %%
a = "Sorrawit Suppalabwattana"
a.find("r")
# Out:
# 2

# %%
a = "sorrawit Suppalabwattana"
a.capitalize()
# Out:
# 'Sorrawit suppalabwattana'

# %%
a = "sorrawit Suppalabwattana"
a2 = a.replace("wit","")
a3 = a2.upper()

# %%
a3
# Out:
# 'SORRA SUPPALABWATTANA'

# %%
a = "Brook" + "\n"
a.rstrip()
# Out:
# 'Brook'

# %%
a = "Brook" + "\n"
a[3]
# Out:
# 'o'

# %%
a = "123"
a.join("abc")
# Out:
# 'a123b123c'

# %%
" ".join("abc")
# Out:
# 'a b c'

# %%
a = ("Hello World")
a.split()
# Out:
# ['Hello', 'World']

# %% [markdown]
# Ex4

# %%
L = []
L
# Out:
# []

# %%
L.append("4")
L.append("คน")
L.append("4")
L.append("คน")
L
# Out:
# ['4', 'คน', '4', 'คน']

# %%
L.remove("4")
L
# Out:
# ['คน', '4', 'คน']

# %%
L.pop(0)
L
# Out:
# ['4', 'คน']

# %%
L = [[1,2,3],
     [4,5,6],
     [7,8,9]]
L
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
L.reverse()
L
# Out:
# [[7, 8, 9], [4, 5, 6], [1, 2, 3]]

# %% [markdown]
# Ex5

# %%
LL = L + [2,3,5]
LL
# Out:
# [[7, 8, 9], [4, 5, 6], [1, 2, 3], 2, 3, 5]
